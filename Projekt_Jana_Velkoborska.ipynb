# %% [markdown]
# <a href="https://colab.research.google.com/github/Jana2333/Projekt_Pandas/blob/main/Projekt_Jana_Velkoborska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aktivni stanice:**
# Jsou **vsechny** krome stanice **City Chambers Launch Station**.
#
# **Neaktivni stanice:**
# City Chambers Launch Station, kde byla pouze 1 vypujcka, ale zadna vratka.
#
# **Nejfrekventovanejsi stanice - pocet vypujcek od 15000 vice**:
#
#  Bristo Square,
#  Brunswick Place,
#  Canonmill',
#  Castle Street,
#  Cramond Foreshore,
#  Duke Street,
#  Dundee Terrace,
#  Fountainbridge,
#  Leith Walk,
#  Meadow Plac',
#  Meadows East,
#  Pollock Halls,
#  Portobello - Kings Road,
#  St Andrew Square,
#  Victoria Quay,
#  Waverley Bridge
#
# **Stanice, kde kola chybi:**
#
# 'Belford Road',
#  'Borrowman Square',
#  'Bristo Square',
#  'Bruntsfield',
#  'Bruntsfield Links',
#  'Bruntsfield links',
#  'Castle Street',
#  'Castle Terrace',
#  'Causewayside',
#  'Chambers Street',
#  'Charlotte Square',
#  'City Chambers',
#  'Colinton Road',
#  'Crichton Street',
#  'Dalmeny Station',
#  'Drumsheugh Place',
#  'Dunbar’s Close Garden',
#  'Dundee Terrace',
#  'EICC',
#  'East London Street',
#  'Eden Locke - Aparthotel (RESIDENTS ONLY)',
#  'Edinburgh Zoo',
#  'Ellersly Road',
#  'Forth Bridge Visitors Centre',
#  'Fountain Court  - Apartments (RESIDENTS ONLY)',
#  'Fountainbridge',
#  'Gibson Terrace',
#  'Gladstone Terrace',
#  'Grassmarket',
#  'HSBC UK Lets Ride - Meadows Event',
#  'Haymarket - Murrayfield Rugby Event',
#  'Haymarket Station',
#  'Haymarket Terrace',
#  'Heriot Watt - Student Accommodation',
#  'Heriot Watt - Student Accomodation (Anna MacLeod Halls)',
#  "Holyrood Park - Woman's Tour Of Scotland (Event 11/08/19)",
#  'Hunter Square',
#  'Ingliston Park and Ride (19th to 23rd June)',
#  'Kings Building 3',
#  'Kings Buildings 4',
#  'Lauriston Place',
#  'Lothian Road',
#  'Marchmont Crescent',
#  'Meadow Place',
#  'Meadow Place 2',
#  'Meadows - Edinburgh Climate Festival',
#  'Meadows East',
#  'Murrayfield',
#  'Orchard Brae House',
#  'Picardy Place',
#  'Pleasance Courtyard',
#  'Pollock Halls',
#  'Pollock Halls Virtual',
#  'Queen Margaret University',
#  'RHC - Edinburgh Festival Camping (05th to 26th August)',
#  'Roseburn Street',
#  'Royal Commonwealth Pool',
#  'Royal Edinburgh Hospital',
#  'Scotstoun House',
#  'Simon Square',
#  'St Andrew Square',
#  'St Andrews House',
#  'Surgeons Hall',
#  'Sustrans - walk cycle event',
#  'Tesco Ferrymuir',
#  'The Tron',
#  'Thirlestane Road',
#  'Tollcross',
#  'Warrender Park Road',
#  'Waverley Bridge',
#  'Waverley Court',
#  'Waverley Station',
#  'West Crosscauseway',
#  'West Newington Place',
#  'Whitehouse Loan'
#
# **Stanice, kde se kola hromadi:**
#
# 'Abbeyhill',
#  'Balgreen',
#  'Balgreen Road',
#  'Boroughmuir',
#  'Brunswick Place',
#  'Brunswick Place - Virtual',
#  'Canonmills',
#  'Comely Bank Road',
#  'Constitution Street',
#  'Corn Exchange - walk cycle event',
#  'Corstorphine Road',
#  'Corstorphine Road - Pinkhill',
#  'Craigleith Road',
#  'Cramond Foreshore',
#  'Cycling Scotland Conference',
#  'Dalry Road Co-op',
#  'Dalry Road Lidl',
#  'Dean Street',
#  'Depot',
#  'Depot Virtual',
#  'Drummond Street',
#  'Dudley Gardens',
#  'Duke Street',
#  'Dundas Street',
#  'Dynamic Earth',
#  'Edinburgh Park Central',
#  'Edinburgh Park Station',
#  'Edinburgh Royal Infirmary',
#  'Fort Kinnaird',
#  "Gamekeeper's Road",
#  'George Square',
#  'Gorgie Road',
#  'Hawes Pier',
#  'Henderson Row',
#  'Heriot Watt - Edinburgh Business School',
#  'Hillside Crescent',
#  'Hillside Crescent 1',
#  'Hillside Crescent 2',
#  'Holyrood Road',
#  'Hopetoun Road',
#  'IGMM',
#  'IGMM - Western General',
#  'Ingliston Park & Ride',
#  'Inverleith Row',
#  'Joppa',
#  'Kings Building 2',
#  'Kings Buildings - Murchison House',
#  'Kings Buildings 1',
#  'Launch Day Event',
#  'Leith Links',
#  'Leith Walk',
#  'Leith Walk North',
#  'Logie Green Road',
#  'Macdonald Road',
#  'McDonald Road',
#  'Meggetland',
#  'Milton Road - Edinburgh College',
#  'Morningside Road',
#  'Murrayfield Avenue',
#  'Murrayfield Tram',
#  'Musselburgh Brunton Hall',
#  'Musselburgh Lidl',
#  'Newhaven Road / Dudley Gardens',
#  'Newkirkgate',
#  'Novotel',
#  'Ocean Terminal',
#  'Pleasance - Edinburgh University Sports Fair',
#  'Port Edgar Marina',
#  'Portobello',
#  'Portobello - Kings Road',
#  'Queensferry Road',
#  'Riego Street',
#  'Royal Highland Show - East Gate (19th to 23rd June)',
#  'Royal Highland Show - West Gate (19th to 23rd June)',
#  'Royal Infirmary',
#  'Scotland Street',
#  'Shrubhill',
#  'Sighthill - Edinburgh College',
#  'South Trinity Road',
#  "St. John's Road 1",
#  "St. John's Road 2",
#  'Stockbridge',
#  'The Loan',
#  'Victoria Park',
#  'Victoria Quay',
#  'Waitrose Comely Bank',
#  'Waitrose, Comely Bank',
#  'Wester Coates Terrace',
#  'Western General',
#  'Western General Hospital',
#  'Whitehouse Road'
#
# **Stanice, kde je stejny pocet na zacatku i konci vypujcky**
#
# 'Crescent House', 'Picady Place'
#
# **Vzdalenost mezi stanicemi**
#
# 'Charlotte Square a St Andrew Square je 0.94 km',
#  'Charlotte Square a Canonmills je 1.35 km',
#  'Charlotte Square a Victoria Quay je 3.49 km',
#  'St Andrew Square a St Andrew Square je 0.01 km',
#  'St Andrew Square a Canonmills je 0.92 km',
#  'St Andrew Square a Victoria Quay je 2.8 km',
#  'Canonmills a St Andrew Square je 0.93 km',
#  'Canonmills a Canonmills je 0.0 km',
#  'Canonmills a Victoria Quay je 2.15 km',
#  'Kings Buildings 4 a Kings Building 3 je 0.19 km',
#  'Kings Buildings 4 a Kings Building 2 je 0.35 km',
#  'Kings Buildings 4 a Kings Buildings 1 je 0.31 km',
#  'Kings Buildings 4 a Pollock Halls je 2.03 km',
#  'Kings Buildings 4 a Royal Commonwealth Pool je 1.9 km',
#  'Kings Buildings 4 a Meadows East je 2.02 km',
#  'Kings Buildings 4 a Bristo Square je 2.77 km',
#  'Kings Building 2 a Kings Building 3 je 0.24 km',
#  'Kings Building 2 a Kings Building 2 je 0.0 km',
#  'Kings Building 2 a Kings Buildings 1 je 0.18 km',
#  'Kings Building 2 a Pollock Halls je 1.87 km',
#  'Kings Building 2 a Royal Commonwealth Pool je 1.76 km',
#  'Kings Building 2 a Meadows East je 1.97 km',
#  'Kings Building 2 a Bristo Square je 2.75 km',
#  'Kings Buildings 1 a Kings Building 3 je 0.12 km',
#  'Kings Buildings 1 a Kings Building 2 je 0.18 km',
#  'Kings Buildings 1 a Kings Buildings 1 je 0.0 km',
#  'Kings Buildings 1 a Pollock Halls je 1.76 km',
#  'Kings Buildings 1 a Royal Commonwealth Pool je 1.65 km',
#  'Kings Buildings 1 a Meadows East je 1.83 km',
#  'Kings Buildings 1 a Bristo Square je 2.6 km',
#  'Kings Building 3 a Kings Building 3 je 0.0 km',
#  'Kings Building 3 a Kings Building 2 je 0.24 km',
#  'Kings Building 3 a Kings Buildings 1 je 0.12 km',
#  'Kings Building 3 a Pollock Halls je 1.85 km',
#  'Kings Building 3 a Royal Commonwealth Pool je 1.73 km',
#  'Kings Building 3 a Meadows East je 1.88 km',
#  'Kings Building 3 a Bristo Square je 2.64 km',
#  'Pollock Halls a Kings Building 3 je 1.85 km',
#  'Pollock Halls a Kings Building 2 je 1.87 km',
#  'Pollock Halls a Kings Buildings 1 je 1.76 km',
#  'Pollock Halls a Pollock Halls je 0.0 km',
#  'Pollock Halls a Royal Commonwealth Pool je 0.18 km',
#  'Pollock Halls a Meadows East je 0.7 km',
#  'Pollock Halls a Bristo Square je 1.26 km',
#  'Royal Commonwealth Pool a Kings Building 3 je 1.73 km',
#  'Royal Commonwealth Pool a Kings Building 2 je 1.76 km',
#  'Royal Commonwealth Pool a Kings Buildings 1 je 1.65 km',
#  'Royal Commonwealth Pool a Pollock Halls je 0.18 km',
#  'Royal Commonwealth Pool a Royal Commonwealth Pool je 0.0 km',
#  'Royal Commonwealth Pool a Meadows East je 0.56 km',
#  'Royal Commonwealth Pool a Bristo Square je 1.21 km',
#  'Meadows East a Kings Building 3 je 1.88 km',
#  'Meadows East a Kings Building 2 je 1.97 km',
#  'Meadows East a Kings Buildings 1 je 1.83 km',
#  'Meadows East a Pollock Halls je 0.7 km',
#  'Meadows East a Royal Commonwealth Pool je 0.56 km',
#  'Meadows East a Meadows East je 0.0 km',
#  'Meadows East a Bristo Square je 0.78 km',
#  'Waverley Bridge a Stockbridge je 1.31 km',
#  'Waverley Bridge a City Chambers je 0.16 km',
#  'Waverley Bridge a Portobello je 4.7 km',
#  'Waverley Bridge a Launch Day Event je 0.98 km',
#  'Waverley Bridge a George Square je 0.94 km',
#  'Waverley Bridge a Charlotte Square je 0.99 km',
#  'Waverley Bridge a Waverley Bridge je 0.0 km',
#  'Waverley Bridge a Fountainbridge je 1.43 km',
#  'Waverley Bridge a Brunswick Place je 1.25 km',
#  'Waverley Bridge a Waverley Station je 0.28 km',
#  'Waverley Bridge a Waverley Court je 0.45 km',
#  'Waverley Bridge a Kings Buildings 4 je 3.39 km',
#  'Waverley Bridge a St Andrews House je 0.64 km',
#  'Waverley Bridge a Lauriston Place je 0.82 km',
#  'Waverley Bridge a Victoria Park je 2.56 km',
#  'City Chambers a Stockbridge je 1.46 km',
#  'City Chambers a City Chambers je 0.0 km',
#  'City Chambers a Portobello je 4.65 km',
#  'City Chambers a Launch Day Event je 0.84 km',
#  'City Chambers a George Square je 0.79 km',
#  'City Chambers a Charlotte Square je 1.08 km',
#  'City Chambers a Waverley Bridge je 0.16 km',
#  'City Chambers a Fountainbridge je 1.4 km',
#  'City Chambers a Brunswick Place je 1.34 km',
#  'City Chambers a Waverley Station je 0.33 km',
#  'City Chambers a Waverley Court je 0.42 km',
#  'City Chambers a Kings Buildings 4 je 3.24 km',
#  'City Chambers a St Andrews House je 0.63 km',
#  'City Chambers a Lauriston Place je 0.74 km',
#  'City Chambers a Victoria Park je 2.7 km',
#  'Portobello a Stockbridge je 5.7 km',
#  'Portobello a City Chambers je 4.65 km',
#  'Portobello a Portobello je 0.0 km',
#  'Portobello a Launch Day Event je 4.92 km',
#  'Portobello a George Square je 4.72 km',
#  'Portobello a Charlotte Square je 5.66 km',
#  'Portobello a Waverley Bridge je 4.7 km',
#  'Portobello a Fountainbridge je 5.97 km',
#  'Portobello a Brunswick Place je 4.03 km',
#  'Portobello a Waverley Station je 4.44 km',
#  'Portobello a Waverley Court je 4.24 km',
#  'Portobello a Kings Buildings 4 je 5.41 km',
#  'Portobello a St Andrews House je 4.07 km',
#  'Portobello a Lauriston Place je 5.2 km',
#  'Portobello a Victoria Park je 5.21 km',
#  'Launch Day Event a Stockbridge je 2.07 km',
#  'Launch Day Event a City Chambers je 0.84 km',
#  'Launch Day Event a Portobello je 4.92 km',
#  'Launch Day Event a Launch Day Event je 0.0 km',
#  'Launch Day Event a George Square je 0.2 km',
#  'Launch Day Event a Charlotte Square je 1.47 km',
#  'Launch Day Event a Waverley Bridge je 0.98 km',
#  'Launch Day Event a Fountainbridge je 1.12 km',
#  'Launch Day Event a Brunswick Place je 2.15 km',
#  'Launch Day Event a Waverley Station je 1.15 km',
#  'Launch Day Event a Waverley Court je 1.12 km',
#  'Launch Day Event a Kings Buildings 4 je 2.46 km',
#  'Launch Day Event a St Andrews House je 1.33 km',
#  'Launch Day Event a Lauriston Place je 0.44 km',
#  'Launch Day Event a Victoria Park je 3.53 km',
#  'Brunswick Place a Stockbridge je 1.71 km',
#  'Brunswick Place a City Chambers je 1.34 km',
#  'Brunswick Place a Portobello je 4.03 km',
#  'Brunswick Place a Launch Day Event je 2.15 km',
#  'Brunswick Place a George Square je 2.04 km',
#  'Brunswick Place a Charlotte Square je 1.89 km',
#  'Brunswick Place a Waverley Bridge je 1.25 km',
#  'Brunswick Place a Fountainbridge je 2.63 km',
#  'Brunswick Place a Brunswick Place je 0.0 km',
#  'Brunswick Place a Waverley Station je 1.01 km',
#  'Brunswick Place a Waverley Court je 1.04 km',
#  'Brunswick Place a Kings Buildings 4 je 4.34 km',
#  'Brunswick Place a St Andrews House je 0.87 km',
#  'Brunswick Place a Lauriston Place je 2.07 km',
#  'Brunswick Place a Victoria Park je 1.7 km',
#  'George Square a Stockbridge je 2.12 km',
#  'George Square a City Chambers je 0.79 km',
#  'George Square a Portobello je 4.72 km',
#  'George Square a Launch Day Event je 0.2 km',
#  'George Square a George Square je 0.0 km',
#  'George Square a Charlotte Square je 1.56 km',
#  'George Square a Waverley Bridge je 0.94 km',
#  'George Square a Fountainbridge je 1.31 km',
#  'George Square a Brunswick Place je 2.04 km',
#  'George Square a Waverley Station je 1.07 km',
#  'George Square a Waverley Court je 1.0 km',
#  'George Square a Kings Buildings 4 je 2.45 km',
#  'George Square a St Andrews House je 1.2 km',
#  'George Square a Lauriston Place je 0.59 km',
#  'George Square a Victoria Park je 3.49 km',
#  'Bristo Square a Stockbridge je 1.85 km',
#  'Bristo Square a City Chambers je 0.47 km',
#  'Bristo Square a Portobello je 4.65 km',
#  'Bristo Square a Launch Day Event je 0.42 km',
#  'Bristo Square a George Square je 0.33 km',
#  'Bristo Square a Charlotte Square je 1.35 km',
#  'Bristo Square a Waverley Bridge je 0.62 km',
#  'Bristo Square a Fountainbridge je 1.32 km',
#  'Bristo Square a Brunswick Place je 1.73 km',
#  'Bristo Square a Waverley Station je 0.74 km',
#  'Bristo Square a Waverley Court je 0.7 km',
#  'Bristo Square a Kings Buildings 4 je 2.77 km',
#  'Bristo Square a St Andrews House je 0.91 km',
#  'Bristo Square a Lauriston Place je 0.55 km',
#  'Bristo Square a Victoria Park je 3.17 km',
#  'Victoria Quay a Stockbridge je 3.0 km',
#  'Victoria Quay a City Chambers je 3.23 km',
#  'Victoria Quay a Portobello je 4.25 km',
#  'Victoria Quay a Launch Day Event je 4.05 km',
#  'Victoria Quay a George Square je 3.95 km',
#  'Victoria Quay a Charlotte Square je 3.49 km',
#  'Victoria Quay a Waverley Bridge je 3.12 km',
#  'Victoria Quay a Fountainbridge je 4.4 km',
#  'Victoria Quay a Brunswick Place je 1.91 km',
#  'Victoria Quay a Waverley Station je 2.91 km',
#  'Victoria Quay a Waverley Court je 2.95 km',
#  'Victoria Quay a Kings Buildings 4 je 6.2 km',
#  'Victoria Quay a St Andrews House je 2.77 km',
#  'Victoria Quay a Lauriston Place je 3.93 km',
#  'Victoria Quay a Victoria Park je 1.33 km',
#  'Fountainbridge a Stockbridge je 1.69 km',
#  'Fountainbridge a City Chambers je 1.4 km',
#  'Fountainbridge a Portobello je 5.97 km',
#  'Fountainbridge a Launch Day Event je 1.12 km',
#  'Fountainbridge a George Square je 1.31 km',
#  'Fountainbridge a Charlotte Square je 1.01 km',
#  'Fountainbridge a Waverley Bridge je 1.43 km',
#  'Fountainbridge a Fountainbridge je 0.0 km',
#  'Fountainbridge a Brunswick Place je 2.63 km',
#  'Fountainbridge a Waverley Station je 1.71 km',
#  'Fountainbridge a Waverley Court je 1.82 km',
#  'Fountainbridge a Kings Buildings 4 je 3.12 km',
#  'Fountainbridge a St Andrews House je 2.04 km',
#  'Fountainbridge a Lauriston Place je 0.77 km',
#  'Fountainbridge a Victoria Park je 3.56 km',
#  'Waverley Court a Stockbridge je 1.68 km',
#  'Waverley Court a City Chambers je 0.42 km',
#  'Waverley Court a Portobello je 4.24 km',
#  'Waverley Court a Launch Day Event je 1.12 km',
#  'Waverley Court a George Square je 1.0 km',
#  'Waverley Court a Charlotte Square je 1.43 km',
#  'Waverley Court a Waverley Bridge je 0.45 km',
#  'Waverley Court a Fountainbridge je 1.82 km',
#  'Waverley Court a Brunswick Place je 1.04 km',
#  'Waverley Court a Waverley Station je 0.23 km',
#  'Waverley Court a Waverley Court je 0.0 km',
#  'Waverley Court a Kings Buildings 4 je 3.34 km',
#  'Waverley Court a St Andrews House je 0.22 km',
#  'Waverley Court a Lauriston Place je 1.13 km',
#  'Waverley Court a Victoria Park je 2.59 km',
#  'Lauriston Place a Stockbridge je 1.68 km',
#  'Lauriston Place a City Chambers je 0.74 km',
#  'Lauriston Place a Portobello je 5.2 km',
#  'Lauriston Place a Launch Day Event je 0.44 km',
#  'Lauriston Place a George Square je 0.59 km',
#  'Lauriston Place a Charlotte Square je 1.04 km',
#  'Lauriston Place a Waverley Bridge je 0.82 km',
#  'Lauriston Place a Fountainbridge je 0.77 km',
#  'Lauriston Place a Brunswick Place je 2.07 km',
#  'Lauriston Place a Waverley Station je 1.07 km',
#  'Lauriston Place a Waverley Court je 1.13 km',
#  'Lauriston Place a Kings Buildings 4 je 2.84 km',
#  'Lauriston Place a St Andrews House je 1.35 km',
#  'Lauriston Place a Lauriston Place je 0.0 km',
#  'Lauriston Place a Victoria Park je 3.29 km',
#  'Waverley Station a Stockbridge je 1.44 km',
#  'Waverley Station a City Chambers je 0.33 km',
#  'Waverley Station a Portobello je 4.44 km',
#  'Waverley Station a Launch Day Event je 1.15 km',
#  'Waverley Station a George Square je 1.07 km',
#  'Waverley Station a Charlotte Square je 1.22 km',
#  'Waverley Station a Waverley Bridge je 0.28 km',
#  'Waverley Station a Fountainbridge je 1.71 km',
#  'Waverley Station a Brunswick Place je 1.01 km',
#  'Waverley Station a Waverley Station je 0.0 km',
#  'Waverley Station a Waverley Court je 0.23 km',
#  'Waverley Station a Kings Buildings 4 je 3.48 km',
#  'Waverley Station a St Andrews House je 0.37 km',
#  'Waverley Station a Lauriston Place je 1.07 km',
#  'Waverley Station a Victoria Park je 2.44 km',
#  'Stockbridge a Stockbridge je 0.0 km',
#  'Stockbridge a City Chambers je 1.46 km',
#  'Stockbridge a Portobello je 5.7 km',
#  'Stockbridge a Launch Day Event je 2.07 km',
#  'Stockbridge a George Square je 2.12 km',
#  'Stockbridge a Charlotte Square je 0.7 km',
#  'Stockbridge a Waverley Bridge je 1.31 km',
#  'Stockbridge a Fountainbridge je 1.69 km',
#  'Stockbridge a Brunswick Place je 1.71 km',
#  'Stockbridge a Waverley Station je 1.44 km',
#  'Stockbridge a Waverley Court je 1.68 km',
#  'Stockbridge a Kings Buildings 4 je 4.51 km',
#  'Stockbridge a St Andrews House je 1.75 km',
#  'Stockbridge a Lauriston Place je 1.68 km',
#  'Stockbridge a Victoria Park je 1.94 km',
#  'Victoria Park a Stockbridge je 1.94 km',
#  'Victoria Park a City Chambers je 2.7 km',
#  'Victoria Park a Portobello je 5.21 km',
#  'Victoria Park a Launch Day Event je 3.53 km',
#  'Victoria Park a George Square je 3.49 km',
#  'Victoria Park a Charlotte Square je 2.56 km',
#  'Victoria Park a Waverley Bridge je 2.56 km',
#  'Victoria Park a Fountainbridge je 3.56 km',
#  'Victoria Park a Brunswick Place je 1.7 km',
#  'Victoria Park a Waverley Station je 2.44 km',
#  'Victoria Park a Waverley Court je 2.59 km',
#  'Victoria Park a Kings Buildings 4 je 5.92 km',
#  'Victoria Park a St Andrews House je 2.48 km',
#  'Victoria Park a Lauriston Place je 3.29 km',
#  'Victoria Park a Victoria Park je 0.0 km',
#  'St Andrews House a Stockbridge je 1.75 km',
#  'St Andrews House a City Chambers je 0.63 km',
#  'St Andrews House a Portobello je 4.07 km',
#  'St Andrews House a Launch Day Event je 1.33 km',
#  'St Andrews House a George Square je 1.2 km',
#  'St Andrews House a Charlotte Square je 1.59 km',
#  'St Andrews House a Waverley Bridge je 0.64 km',
#  'St Andrews House a Fountainbridge je 2.04 km',
#  'St Andrews House a Brunswick Place je 0.87 km',
#  'St Andrews House a Waverley Station je 0.37 km',
#  'St Andrews House a Waverley Court je 0.22 km',
#  'St Andrews House a Kings Buildings 4 je 3.48 km',
#  'St Andrews House a St Andrews House je 0.0 km',
#  'St Andrews House a Lauriston Place je 1.35 km',
#  'St Andrews House a Victoria Park je 2.48 km',
#  'Depot a Depot je 0.0 km',
#  'Shrubhill a Shrubhill je 0.0 km',
#  'Riego Street a Riego Street je 0.0 km',
#  'Waitrose, Comely Bank a Waitrose, Comely Bank je 0.0 km',
#  'Leith Links a Leith Links je 0.0 km',
#  'Ocean Terminal a Ocean Terminal je 0.0 km',
#  'Bruntsfield a Castle Street je 1.61 km',
#  'Bruntsfield a Bruntsfield je 0.0 km',
#  'Royal Infirmary a Royal Infirmary je 0.0 km',
#  'Simon Square a Simon Square je 0.0 km',
#  'Simon Square a Warrender Park Road je 1.2 km',
#  'Warrender Park Road a Simon Square je 1.2 km',
#  'Warrender Park Road a Warrender Park Road je 0.0 km',
#  'Thirlestane Road a Gibson Terrace je 1.29 km',
#  'Thirlestane Road a Dundee Terrace je 1.45 km',
#  'Dalry Road Co-op a Gibson Terrace je 0.36 km',
#  'Dalry Road Co-op a Dundee Terrace je 0.34 km',
#  'Whitehouse Loan a Gibson Terrace je 1.04 km',
#  'Whitehouse Loan a Dundee Terrace je 1.21 km',
#  'Gibson Terrace a Dalry Road Lidl je 0.36 km',
#  'Gibson Terrace a Dalry Road Co-op je 0.36 km',
#  'Gibson Terrace a Whitehouse Loan je 1.04 km',
#  'Gibson Terrace a Macdonald Road je 3.29 km',
#  'Gibson Terrace a Leith Walk je 3.72 km',
#  'Gibson Terrace a East London Street je 2.86 km',
#  'Dalry Road Lidl a Dalry Road Lidl je 0.0 km',
#  'Dalry Road Lidl a Dalry Road Co-op je 0.13 km',
#  'Dalry Road Lidl a Whitehouse Loan je 1.4 km',
#  'Dalry Road Lidl a Macdonald Road je 3.4 km',
#  'Dalry Road Lidl a Leith Walk je 3.86 km',
#  'Dalry Road Lidl a East London Street je 2.99 km',
#  'Dundee Terrace a Dalry Road Lidl je 0.26 km',
#  'Dundee Terrace a Dalry Road Co-op je 0.34 km',
#  'Dundee Terrace a Whitehouse Loan je 1.21 km',
#  'Dundee Terrace a Macdonald Road je 3.49 km',
#  'Dundee Terrace a Leith Walk je 3.93 km',
#  'Dundee Terrace a East London Street je 3.06 km',
#  'Macdonald Road a Dalry Road Lidl je 3.4 km',
#  'Macdonald Road a Dalry Road Co-op je 3.28 km',
#  'Macdonald Road a Whitehouse Loan je 3.26 km',
#  'Macdonald Road a Macdonald Road je 0.0 km',
#  'Macdonald Road a Leith Walk je 0.54 km',
#  'Macdonald Road a East London Street je 0.47 km',
#  'Leith Walk a Marchmont Crescent je 3.37 km',
#  'Marchmont Crescent a Marchmont Crescent je 0.0 km',
#  'East London Street a Marchmont Crescent je 2.66 km',
#  'Orchard Brae House a Marchmont Crescent je 2.77 km',
#  'Inverleith Row a South Trinity Road je 0.87 km',
#  'Inverleith Row a Inverleith Row je 0.0 km',
#  'Inverleith Row a Morningside Road je 4.05 km',
#  'Inverleith Row a Meadow Place je 2.7 km',
#  'Inverleith Row a Thirlestane Road je 3.21 km',
#  'South Trinity Road a South Trinity Road je 0.0 km',
#  'South Trinity Road a Inverleith Row je 0.87 km',
#  'South Trinity Road a Morningside Road je 4.82 km',
#  'South Trinity Road a Meadow Place je 3.55 km',
#  'South Trinity Road a Thirlestane Road je 4.04 km',
#  'Colinton Road a South Trinity Road je 4.15 km',
#  'Colinton Road a Inverleith Row je 3.4 km',
#  'Colinton Road a Morningside Road je 0.68 km',
#  'Colinton Road a Meadow Place je 1.23 km',
#  'Colinton Road a Thirlestane Road je 0.77 km',
#  'Meadow Place a South Trinity Road je 3.55 km',
#  'Meadow Place a Inverleith Row je 2.7 km',
#  'Meadow Place a Morningside Road je 1.67 km',
#  'Meadow Place a Meadow Place je 0.0 km',
#  'Meadow Place a Thirlestane Road je 0.61 km',
#  'Morningside Road a Orchard Brae House je 3.14 km',
#  'Novotel a Novotel je 0.0 km',
#  'Novotel a Causewayside je 1.54 km',
#  'Causewayside a Novotel je 1.54 km',
#  'Causewayside a Causewayside je 0.0 km',
#  'Newhaven Road / Dudley Gardens a Newhaven Road / Dudley Gardens je 0.0 km',
#  'Western General a Western General je 0.0 km',
#  'Pollock Halls Virtual a Pollock Halls Virtual je 0.0 km',
#  'Dundas Street a Dundas Street je 0.0 km',
#  'Dundas Street a Hillside Crescent 2 je 1.66 km',
#  'Hillside Crescent 2 a Hillside Crescent 1 je 0.33 km',
#  'Hillside Crescent 2 a Cramond Foreshore je 8.2 km',
#  'Hillside Crescent 2 a Henderson Row je 1.8 km',
#  'Hillside Crescent 2 a Gladstone Terrace je 2.28 km',
#  'Cramond Foreshore a Hillside Crescent 1 je 7.88 km',
#  'Cramond Foreshore a Cramond Foreshore je 0.0 km',
#  'Cramond Foreshore a Henderson Row je 6.43 km',
#  'Cramond Foreshore a Gladstone Terrace je 8.6 km',
#  'Comely Bank Road a Comely Bank Road je 0.0 km',
#  'Comely Bank Road a Balgreen je 3.18 km',
#  'Comely Bank Road a Crichton Street je 2.44 km',
#  'Comely Bank Road a EICC je 1.52 km',
#  'Comely Bank Road a Roseburn Street je 2.04 km',
#  'Comely Bank Road a Corstorphine Road je 4.0 km',
#  'Comely Bank Road a Whitehouse Road je 5.65 km',
#  'Hillside Crescent 1 a Comely Bank Road je 2.19 km',
#  'Hillside Crescent 1 a Balgreen je 4.88 km',
#  'Hillside Crescent 1 a Crichton Street je 1.51 km',
#  'Hillside Crescent 1 a EICC je 2.28 km',
#  'Hillside Crescent 1 a Roseburn Street je 3.68 km',
#  'Hillside Crescent 1 a Corstorphine Road je 5.95 km',
#  'Hillside Crescent 1 a Whitehouse Road je 7.84 km',
#  'Roseburn Street a Comely Bank Road je 2.04 km',
#  'Roseburn Street a Balgreen je 1.21 km',
#  'Roseburn Street a Crichton Street je 3.0 km',
#  'Roseburn Street a EICC je 1.51 km',
#  'Roseburn Street a Roseburn Street je 0.0 km',
#  'Roseburn Street a Corstorphine Road je 2.33 km',
#  'Roseburn Street a Whitehouse Road je 4.86 km',
#  'EICC a Tollcross je 0.51 km',
#  "EICC a St. John's Road 2 je 5.03 km",
#  'EICC a Murrayfield Avenue je 1.63 km',
#  'Crichton Street a Tollcross je 1.03 km',
#  "Crichton Street a St. John's Road 2 je 6.52 km",
#  'Crichton Street a Murrayfield Avenue je 3.13 km',
#  'Corstorphine Road a Tollcross je 4.29 km',
#  "Corstorphine Road a St. John's Road 2 je 1.21 km",
#  'Corstorphine Road a Murrayfield Avenue je 2.24 km',
#  'Tollcross a Tollcross je 0.0 km',
#  "Tollcross a St. John's Road 2 je 5.49 km",
#  'Tollcross a Murrayfield Avenue je 2.11 km',
#  'Murrayfield Avenue a Tollcross je 2.11 km',
#  "Murrayfield Avenue a St. John's Road 2 je 3.41 km",
#  'Murrayfield Avenue a Murrayfield Avenue je 0.0 km',
#  'Henderson Row a Wester Coates Terrace je 2.38 km',
#  "St. John's Road 2 a Wester Coates Terrace je 3.7 km",
#  'Murrayfield Tram a Wester Coates Terrace je 0.56 km',
#  'Wester Coates Terrace a Wester Coates Terrace je 0.0 km',
#  "Gamekeeper's Road a Wester Coates Terrace je 5.42 km",
#  'Gladstone Terrace a Wester Coates Terrace je 3.04 km',
#  'Balgreen a Craigleith Road je 2.14 km',
#  'Balgreen a Edinburgh Zoo je 1.15 km',
#  'Balgreen a Murrayfield Tram je 0.9 km',
#  "Balgreen a Gamekeeper's Road je 4.89 km",
#  'Craigleith Road a Craigleith Road je 0.0 km',
#  'Craigleith Road a Edinburgh Zoo je 2.51 km',
#  'Craigleith Road a Murrayfield Tram je 1.63 km',
#  "Craigleith Road a Gamekeeper's Road je 4.57 km",
#  'Murrayfield a Craigleith Road je 1.37 km',
#  'Murrayfield a Edinburgh Zoo je 1.59 km',
#  'Murrayfield a Murrayfield Tram je 0.48 km',
#  "Murrayfield a Gamekeeper's Road je 4.84 km",
#  'Edinburgh Zoo a Craigleith Road je 2.51 km',
#  'Edinburgh Zoo a Edinburgh Zoo je 0.0 km',
#  'Edinburgh Zoo a Murrayfield Tram je 1.93 km',
#  "Edinburgh Zoo a Gamekeeper's Road je 3.88 km",
#  'Whitehouse Road a Craigleith Road je 4.3 km',
#  'Whitehouse Road a Edinburgh Zoo je 3.18 km',
#  'Whitehouse Road a Murrayfield Tram je 4.79 km',
#  "Whitehouse Road a Gamekeeper's Road je 0.89 km",
#  'Corstorphine Road - Pinkhill a Murrayfield je 1.38 km',
#  "St. John's Road 1 a St. John's Road 1 je 0.0 km",
#  'Logie Green Road a Logie Green Road je 0.0 km',
#  'West Newington Place a IGMM je 4.28 km',
#  'West Newington Place a Queensferry Road je 3.93 km',
#  'Queensferry Road a IGMM je 0.9 km',
#  'Queensferry Road a Queensferry Road je 0.0 km',
#  'IGMM a IGMM je 0.0 km',
#  'IGMM a Queensferry Road je 0.9 km',
#  'West Crosscauseway a IGMM je 3.6 km',
#  'West Crosscauseway a Queensferry Road je 3.33 km',
#  'Dunbar’s Close Garden a Dunbar’s Close Garden je 0.0 km',
#  'Sustrans - walk cycle event a Corn Exchange - walk cycle event je 2.73 km',
#  'Sustrans - walk cycle event a Sustrans - walk cycle event je 0.0 km',
#  'Corn Exchange - walk cycle event a Corn Exchange - walk cycle event je 0.0 km',
#  'Corn Exchange - walk cycle event a Sustrans - walk cycle event je 2.73 km',
#  'Hillside Crescent a Hillside Crescent je 0.0 km',
#  'Ingliston Park and Ride (19th to 23rd June) a Ingliston Park and Ride (19th to 23rd June) je 0.0 km',
#  'Ingliston Park and Ride (19th to 23rd June) a Royal Highland Show - West Gate (19th to 23rd June) je 1.62 km',
#  'Royal Highland Show - East Gate (19th to 23rd June) a Ingliston Park and Ride (19th to 23rd June) je 0.83 km',
#  'Royal Highland Show - East Gate (19th to 23rd June) a Royal Highland Show - West Gate (19th to 23rd June) je 0.8 km',
#  'Royal Highland Show - West Gate (19th to 23rd June) a Ingliston Park and Ride (19th to 23rd June) je 1.62 km',
#  'Royal Highland Show - West Gate (19th to 23rd June) a Royal Highland Show - West Gate (19th to 23rd June) je 0.0 km',
#  'Meadows - Edinburgh Climate Festival a Meadows - Edinburgh Climate Festival je 0.0 km',
#  'Hunter Square a Hunter Square je 0.0 km',
#  'Grassmarket a Grassmarket je 0.0 km',
#  'Meadow Place 2 a Meadow Place 2 je 0.0 km',
#  'Meadow Place 2 a Bruntsfield links je 0.81 km',
#  'Bruntsfield links a Constitution Street je 4.93 km',
#  'Constitution Street a Constitution Street je 0.0 km',
#  'Drummond Street a Drummond Street je 0.0 km',
#  'The Tron a The Tron je 0.0 km',
#  'Eden Locke - Aparthotel (RESIDENTS ONLY) a Fountain Court  - Apartments (RESIDENTS ONLY) je 1.04 km',
#  "Holyrood Park - Woman's Tour Of Scotland (Event 11/08/19) a Holyrood Park - Woman's Tour Of Scotland (Event 11/08/19) je 0.0 km",
#  'Queen Margaret University a Queen Margaret University je 0.0 km',
#  'Fountain Court  - Apartments (RESIDENTS ONLY) a Eden Locke - Aparthotel (RESIDENTS ONLY) je 1.04 km',
#  'Haymarket - Murrayfield Rugby Event a Haymarket - Murrayfield Rugby Event je 0.0 km',
#  'Lothian Road a Lothian Road je 0.0 km',
#  'Milton Road - Edinburgh College a Kings Buildings - Murchison House je 5.46 km',
#  'Kings Buildings - Murchison House a Kings Buildings - Murchison House je 0.0 km',
#  'Sighthill - Edinburgh College a Sighthill - Edinburgh College je 0.0 km',
#  'Sighthill - Edinburgh College a Brunswick Place - Virtual je 7.78 km',
#  'Brunswick Place - Virtual a Sighthill - Edinburgh College je 7.78 km',
#  'Brunswick Place - Virtual a Brunswick Place - Virtual je 0.0 km',
#  'Fort Kinnaird a Pleasance - Edinburgh University Sports Fair je 5.03 km',
#  'Holyrood Road a Holyrood Road je 0.0 km',
#  'Holyrood Road a Belford Road je 2.87 km',
#  'Pleasance - Edinburgh University Sports Fair a Holyrood Road je 0.17 km',
#  'Pleasance - Edinburgh University Sports Fair a Belford Road je 2.81 km',
#  'Belford Road a Holyrood Road je 2.87 km',
#  'Belford Road a Belford Road je 0.0 km',
#  'HSBC UK Lets Ride - Meadows Event a HSBC UK Lets Ride - Meadows Event je 0.0 km',
#  'Haymarket Station a Haymarket Station je 0.0 km',
#  'Heriot Watt - Edinburgh Business School a Heriot Watt - Student Accomodation (Anna MacLeod Halls) je 0.54 km',
#  'Heriot Watt - Edinburgh Business School a Heriot Watt - Edinburgh Business School je 0.0 km',
#  'Heriot Watt - Student Accomodation (Anna MacLeod Halls) a Heriot Watt - Student Accomodation (Anna MacLeod Halls) je 0.0 km',
#  'Heriot Watt - Student Accomodation (Anna MacLeod Halls) a Heriot Watt - Edinburgh Business School je 0.54 km',
#  'Surgeons Hall a Surgeons Hall je 0.0 km',
#  'Portobello - Kings Road a Portobello - Kings Road je 0.0 km',
#  'Portobello - Kings Road a McDonald Road je 4.23 km',
#  'McDonald Road a Portobello - Kings Road je 4.23 km',
#  'McDonald Road a McDonald Road je 0.0 km',
#  'Pleasance Courtyard a Portobello - Kings Road je 4.12 km',
#  'Pleasance Courtyard a McDonald Road je 1.85 km',
#  'Cycling Scotland Conference a Cycling Scotland Conference je 0.0 km',
#  'Crescent House a Crescent House je 0.0 km',
#  'Scotland Street a Scotland Street je 0.0 km',
#  'Edinburgh Royal Infirmary a Dean Street je 6.16 km',
#  'IGMM - Western General a IGMM - Western General je 0.0 km',
#  'IGMM - Western General a Waitrose Comely Bank je 0.63 km',
#  'Waitrose Comely Bank a IGMM - Western General je 0.63 km',
#  'Waitrose Comely Bank a Waitrose Comely Bank je 0.0 km',
#  'Bruntsfield Links a Bruntsfield Links je 0.0 km',
#  'Ellersly Road a Ellersly Road je 0.0 km',
#  'Royal Edinburgh Hospital a Royal Edinburgh Hospital je 0.0 km',
#  'Abbeyhill a Abbeyhill je 0.0 km',
#  'Drumsheugh Place a Duke Street je 3.41 km',
#  'Drumsheugh Place a Drumsheugh Place je 0.0 km',
#  'Boroughmuir a Duke Street je 4.4 km',
#  'Boroughmuir a Drumsheugh Place je 1.3 km',
#  'Duke Street a Edinburgh Park Station je 9.9 km',
#  'Duke Street a Boroughmuir je 4.4 km',
#  'Edinburgh Park Station a Edinburgh Park Station je 0.0 km',
#  'Edinburgh Park Station a Boroughmuir je 5.93 km',
#  'The Loan a The Loan je 0.0 km',
#  'Borrowman Square a Borrowman Square je 0.0 km',
#  'Dalmeny Station a Borrowman Square je 0.47 km',
#  'Hopetoun Road a Hopetoun Road je 0.0 km',
#  'Hawes Pier a Dalmeny Station je 0.46 km',
#  'Hawes Pier a Hawes Pier je 0.0 km',
#  'Scotstoun House a Dalmeny Station je 0.97 km',
#  'Scotstoun House a Hawes Pier je 1.18 km',
#  'Tesco Ferrymuir a Ingliston Park & Ride je 5.77 km',
#  'Port Edgar Marina a Port Edgar Marina je 0.0 km',
#  'Port Edgar Marina a Tesco Ferrymuir je 1.09 km',
#  'Musselburgh Lidl a Musselburgh Lidl je 0.0 km',
#  'Musselburgh Brunton Hall a Musselburgh Brunton Hall je 0.0 km',
#  'Picady Place a Picady Place je 0.0 km',
#  'Picady Place a Picardy Place je 0.0 km',
#  'Picardy Place a Picady Place je 0.0 km',
#  'Picardy Place a Picardy Place je 0.0 km'
#
# **Delka vypujcky**
#
# Nejkratsi vypujcka trva 61 vterin.
#
# Nejdelsi vypujcka trva 2 363 348 vterin (27.35 dni).
#
# Prumerna doba vypujcky trva 32,5 minuty.
#
# **Odlehlé hodnoty jsou na techto radcich:**
#
# 'index = 1322', 'odlehla hodnota = 500807',
#
# 'index = 2130', 'odlehla hodnota = 2363348',
#
# 'index = 2733', 'odlehla hodnota = 1000750',
#
# 'index = 766', 'odlehla hodnota = 688832',
#
# 'index = 3151', 'odlehla hodnota = 631452',
#
# 'index = 2206', 'odlehla hodnota = 1032838',
#
# 'index = 3445', 'odlehla hodnota = 701168'
#
#
# **Identifikace vykyvu poptavky:**
#
# V letnich mesicich je v prumeru vice poptavek po pujcovani kol vzhledem k vyssim teplotam.
#
# Mnozstvi poptavek nad 1500 za den je v letnich mesicich roku 2020.
#
# Vliv ma prizniva teplota kolem 15 nebo nizsi vitr, popr. narazovy vitr.
#  ('datum 20/5/2020', 'teplota 10.5', 'vitr 14.88', 'narazovy vitr 23.5'),
#  ('datum 25/5/2020', 'teplota 12.88', 'vitr 26.5', 'narazovy vitr 43.12'),
#  ('datum 28/5/2020', 'teplota 13.88', 'vitr 18.0', 'narazovy vitr 29.88'),
#  ('datum 29/5/2020', 'teplota 14.12', 'vitr 16.88', 'narazovy vitr 28.5'),
#  ('datum 30/5/2020', 'teplota 11.75', 'vitr 34.75', 'narazovy vitr 55.62'),
#  ('datum 31/5/2020', 'teplota 10.12', 'vitr 21.5', 'narazovy vitr 31.88'),
#  ('datum 1/6/2020', 'teplota 8.88', 'vitr 21.88', 'narazovy vitr 33.75'),
#  ('datum 6/6/2020', 'teplota 8.88', 'vitr 21.0', 'narazovy vitr 33.0'),
#  ('datum 20/6/2020', 'teplota 7.5', 'vitr 12.25', 'narazovy vitr 19.75'),
#  ('datum 24/6/2020', 'teplota 8.62', 'vitr 16.75', 'narazovy vitr 27.0'),
#  ('datum 25/6/2020', 'teplota 10.5', 'vitr 26.38', 'narazovy vitr 40.5'),
#  ('datum 11/7/2020', 'teplota 15.38', 'vitr 32.38', 'narazovy vitr 51.5'),
#  ('datum 31/7/2020', 'teplota 12.5', 'vitr 24.12', 'narazovy vitr 38.88'),
#  ('datum 8/8/2020', 'teplota 8.12', 'vitr 11.88', 'narazovy vitr 17.88')
#
# V podzimnich a zimnich mesicich 2018 a 2019 je poptavka nizsi.
# Vliv na poptavku pod 100 za den ma vyssi narazovy vitr. Teplota ma vliv nevyrazny.
#
#  ('datum 15/9/2018', 'teplota 10.5', 'vitr 14.88', 'narazovy vitr 23.5'),
#  ('datum 16/9/2018', 'teplota 12.88', 'vitr 26.5', 'narazovy vitr 43.12'),
#  ('datum 19/9/2018', 'teplota 13.88', 'vitr 18.0', 'narazovy vitr 29.88'),
#  ('datum 21/9/2018', 'teplota 14.12', 'vitr 16.88', 'narazovy vitr 28.5'),
#  ('datum 1/10/2018', 'teplota 11.75', 'vitr 34.75', 'narazovy vitr 55.62'),
#  ('datum 7/10/2018', 'teplota 10.12', 'vitr 21.5', 'narazovy vitr 31.88'),
#  ('datum 8/10/2018', 'teplota 8.88', 'vitr 21.88', 'narazovy vitr 33.75'),
#  ('datum 9/10/2018', 'teplota 8.88', 'vitr 21.0', 'narazovy vitr 33.0'),
#  ('datum 12/10/2018', 'teplota 7.5', 'vitr 12.25', 'narazovy vitr 19.75'),
#  ('datum 13/10/2018', 'teplota 8.62', 'vitr 16.75', 'narazovy vitr 27.0'),
#  ('datum 24/10/2018', 'teplota 10.5', 'vitr 26.38', 'narazovy vitr 40.5'),
#  ('datum 20/11/2018', 'teplota 15.38', 'vitr 32.38', 'narazovy vitr 51.5'),
#  ('datum 22/11/2018', 'teplota 12.5', 'vitr 24.12', 'narazovy vitr 38.88'),
#  ('datum 24/11/2018', 'teplota 8.12', 'vitr 11.88', 'narazovy vitr 17.88'),
#  ('datum 4/12/2018', 'teplota 9.0', 'vitr 27.62', 'narazovy vitr 41.12'),
#  ('datum 7/12/2018', 'teplota 8.88', 'vitr 21.12', 'narazovy vitr 33.5'),
#  ('datum 23/12/2018', 'teplota 7.12', 'vitr 17.12', 'narazovy vitr 28.25'),
#  ('datum 24/12/2018', 'teplota 10.25', 'vitr 25.25', 'narazovy vitr 39.5'),
#  ('datum 26/12/2018', 'teplota 10.5', 'vitr 20.62', 'narazovy vitr 33.12'),
#  ('datum 2/2/2019', 'teplota 12.12', 'vitr 23.75', 'narazovy vitr 38.38'),
#  ('datum 3/2/2019', 'teplota 8.5', 'vitr 11.0', 'narazovy vitr 16.75'),
#  ('datum 9/2/2019', 'teplota 7.12', 'vitr 9.75', 'narazovy vitr 14.88'),
#  ('datum 10/3/2019', 'teplota 8.88', 'vitr 29.88', 'narazovy vitr 47.62'),
#  ('datum 16/3/2019', 'teplota 13.5', 'vitr 33.75', 'narazovy vitr 52.62'),
#  ('datum 6/4/2019', 'teplota 14.0', 'vitr 33.75', 'narazovy vitr 52.62'),
#  ('datum 7/4/2019', 'teplota 14.5', 'vitr 14.75', 'narazovy vitr 25.75'),
#  ('datum 26/12/2020', 'teplota 13.62', 'vitr 17.5', 'narazovy vitr 27.62'),
#  ('datum 29/12/2020', 'teplota 12.25', 'vitr 22.12', 'narazovy vitr 36.12'),
#  ('datum 31/12/2020', 'teplota 12.25', 'vitr 15.0', 'narazovy vitr 24.62'),
#  ('datum 2/1/2021', 'teplota 8.88', 'vitr 11.62', 'narazovy vitr 17.88'),
#  ('datum 3/1/2021', 'teplota 8.38', 'vitr 6.0', 'narazovy vitr 9.75'),
#  ('datum 4/1/2021', 'teplota 9.62', 'vitr 15.5', 'narazovy vitr 26.38'),
#  ('datum 7/1/2021', 'teplota 9.75', 'vitr 16.38', 'narazovy vitr 26.0'),
#  ('datum 20/1/2021', 'teplota 7.38', 'vitr 8.88', 'narazovy vitr 14.0'),
#  ('datum 21/1/2021', 'teplota 8.5', 'vitr 17.38', 'narazovy vitr 28.38'),
#  ('datum 3/2/2021', 'teplota 12.5', 'vitr 19.0', 'narazovy vitr 30.12'),
#  ('datum 9/2/2021', 'teplota 12.0', 'vitr 23.25', 'narazovy vitr 36.5'),
#  ('datum 10/2/2021', 'teplota 8.88', 'vitr 29.12', 'narazovy vitr 45.12'),
#  ('datum 11/2/2021', 'teplota 12.12', 'vitr 39.25', 'narazovy vitr 59.38'),
#  ('datum 12/2/2021', 'teplota 11.0', 'vitr 27.62', 'narazovy vitr 42.0'),
#  ('datum 13/2/2021', 'teplota 11.0', 'vitr 26.88', 'narazovy vitr 40.25'),
#  ('datum 14/2/2021', 'teplota 6.25', 'vitr 20.38', 'narazovy vitr 31.62')
#
#
#
# **Vliv pocasi na poptavku:**
#
# Viz. graf fliv pocasi na poptavku.
#
# Prumerne si lide mene pujcuji kola, kdyz je vetsi narazovy vitr.
#
# Bezny vitr ma take vliv, cim mensi vitr, tim vice vypujcek.
#
# Dest na poptavku nema vliv.
#
# Pocitova teplota kopiruje venkovni teplotu a ma nevyrazny vliv na poptavku.
#
# **Pujcovani kol vikend / vsedni den**
#
# Lide si pujcuji vice kol ve vsedni den (300364 vypujcek), o vikendu jen
# 137895 a vraci vice kol ve vsedni den (300225) a o vikendu vraci jen 138034.

# %%
import pandas as pd
import numpy as np
import sqlalchemy
import matplotlib.pyplot as plt

# !pip install pymysql
student_conn_string = "mysql+pymysql://student:p7%40vw7MCatmnKjy7@data.engeto.com/data"
alchemy_conn = sqlalchemy.create_engine(student_conn_string)

eb_df = pd.read_sql('select * from edinburgh_bikes',alchemy_conn)
ew_df = pd.read_sql('select * from edinburgh_weather',alchemy_conn)

# %%
# prejmenovani sloupcu, abycho mohla spojit tabulky se souctem pocatku vypujcek a vraceni kol
eb1_rename=eb_df.rename(columns=({'start_station_id':'id','start_station_name':'station'}))
eb2_rename=eb_df.rename(columns=({'end_station_id':'id','end_station_name':'station'}))

# %%
eb1_rename.head()
# Out:
#    index           started_at  ... end_station_latitude  end_station_longitude
# 0      0  2018-09-15 08:52:05  ...            55.954728              -3.192653
# 1      1  2018-09-15 09:24:33  ...            55.962804              -3.196284
# 2      2  2018-09-15 09:48:54  ...            55.977638              -3.174116
# 3      3  2018-09-16 12:01:36  ...            55.923479              -3.175385
# 4      4  2018-09-16 12:03:43  ...            55.923202              -3.171646
#
# [5 rows x 14 columns]

# %%
eb2_rename.head()
# Out:
#    index           started_at  ... end_station_latitude  end_station_longitude
# 0      0  2018-09-15 08:52:05  ...            55.954728              -3.192653
# 1      1  2018-09-15 09:24:33  ...            55.962804              -3.196284
# 2      2  2018-09-15 09:48:54  ...            55.977638              -3.174116
# 3      3  2018-09-16 12:01:36  ...            55.923479              -3.175385
# 4      4  2018-09-16 12:03:43  ...            55.923202              -3.171646
#
# [5 rows x 14 columns]

# %%
# tvorba sloupce pocet na zacatku vypujcky kola
pocet_pocatek=eb1_rename.assign(pocet1_start=1).groupby('station').agg({'pocet1_start': 'sum'})
pocet_pocatek.head()
# Out:
#                pocet1_start
# station
# Abbeyhill              4686
# Balgreen                 85
# Balgreen Road          1884
# Belford Road           1116
# Boroughmuir            3976

# %%
# tvorba sloupce pocet pri vraceni kola
pocet_vraceno=eb2_rename.assign(pocet2_konec=1).groupby('station').agg({'pocet2_konec': 'sum'})
pocet_vraceno.head()
# Out:
#                pocet2_konec
# station
# Abbeyhill              5279
# Balgreen                104
# Balgreen Road          2243
# Belford Road           1030
# Boroughmuir            4245

# %%
# spojeni obou souctu k dalsimu vypoctu
spojeni_souctu=pocet_pocatek.join(pocet_vraceno)
spojeni_souctu.head()
# Out:
#                pocet1_start  pocet2_konec
# station
# Abbeyhill              4686        5279.0
# Balgreen                 85         104.0
# Balgreen Road          1884        2243.0
# Belford Road           1116        1030.0
# Boroughmuir            3976        4245.0

# %%
# vypocet nejaktivnejsi, nejmene aktivni stanice a neaktivni stanice
spojeni_souctu['soucet_celkem']=spojeni_souctu['pocet1_start']+spojeni_souctu['pocet2_konec']
spojeni_souctu.sort_values("soucet_celkem",ascending=False)
# Out:
#                                                     pocet1_start  ...  soucet_celkem
# station                                                           ...
# Meadows East                                               17390  ...        32615.0
# Portobello - Kings Road                                    11843  ...        28499.0
# Victoria Quay                                              10662  ...        25916.0
# Meadow Place                                               12464  ...        22260.0
# Canonmills                                                  9551  ...        21491.0
# ...                                                          ...  ...            ...
# Depot                                                          2  ...            5.0
# Royal Highland Show - West Gate (19th to 23rd J...             1  ...            3.0
# Cycling Scotland Conference                                    1  ...            3.0
# ...

# %%
# zruseni indexu na sloupec station
spojeni_souctu_nejaktivnejsi=spojeni_souctu.reset_index("station")
spojeni_souctu_nejaktivnejsi.head()
# Out:
#          station  pocet1_start  pocet2_konec  soucet_celkem
# 0      Abbeyhill          4686        5279.0         9965.0
# 1       Balgreen            85         104.0          189.0
# 2  Balgreen Road          1884        2243.0         4127.0
# 3   Belford Road          1116        1030.0         2146.0
# 4    Boroughmuir          3976        4245.0         8221.0

# %%
# nejaktivnejsi stanice
nejaktivnejsi_stanice=[]
delka_spojeni_souctu_nejaktivnejsi=spojeni_souctu_nejaktivnejsi.shape
for i in range(delka_spojeni_souctu_nejaktivnejsi[0]):
  if spojeni_souctu_nejaktivnejsi["soucet_celkem"].loc[i]>15000:
    nejaktivnejsi_stanice.append(spojeni_souctu_nejaktivnejsi["station"].loc[i])
nejaktivnejsi_stanice
# Out:
# ['Bristo Square',
#  'Brunswick Place',
#  'Canonmills',
#  'Castle Street',
#  'Cramond Foreshore',
#  'Duke Street',
#  'Dundee Terrace',
#  'Fountainbridge',
#  'Leith Walk',
#  'Meadow Place',
#  'Meadows East',
#  'Pollock Halls',
#  'Portobello - Kings Road',
#  'St Andrew Square',
#  'Victoria Quay',
#  'Waverley Bridge']

# %%
# zruseni indexu na sloupec station
spojeni_souctu_hromadi_se=spojeni_souctu.reset_index("station")
spojeni_souctu_hromadi_se.head()
# Out:
#          station  pocet1_start  pocet2_konec  soucet_celkem
# 0      Abbeyhill          4686        5279.0         9965.0
# 1       Balgreen            85         104.0          189.0
# 2  Balgreen Road          1884        2243.0         4127.0
# 3   Belford Road          1116        1030.0         2146.0
# 4    Boroughmuir          3976        4245.0         8221.0

# %%
# stanice, kde se kola hromadi
hromadi_se=[]
chybi=[]
stejne_zacatek_konec=[]
delka_spojeni_souctu_hromadi_se=spojeni_souctu_hromadi_se.shape
for i in range(delka_spojeni_souctu_hromadi_se[0]):
  if spojeni_souctu_hromadi_se["pocet2_konec"].loc[i]-spojeni_souctu_hromadi_se["pocet1_start"].loc[i]>=1:
    hromadi_se.append(spojeni_souctu_hromadi_se["station"].loc[i])
  elif spojeni_souctu_hromadi_se["pocet2_konec"].loc[i]-spojeni_souctu_hromadi_se["pocet1_start"].loc[i]==0:
    stejne_zacatek_konec.append(spojeni_souctu_hromadi_se["station"].loc[i])
  elif spojeni_souctu_hromadi_se["pocet2_konec"].loc[i]-spojeni_souctu_hromadi_se["pocet1_start"].loc[i]<0:
    chybi.append(spojeni_souctu_hromadi_se["station"].loc[i])
hromadi_se
# Out:
# ['Abbeyhill',
#  'Balgreen',
#  'Balgreen Road',
#  'Boroughmuir',
#  'Brunswick Place',
#  'Brunswick Place - Virtual',
#  'Canonmills',
#  'Comely Bank Road',
#  'Constitution Street',
#  'Corn Exchange - walk cycle event',
#  'Corstorphine Road',
#  'Corstorphine Road - Pinkhill',
#  'Craigleith Road',
#  'Cramond Foreshore',
#  'Cycling Scotland Conference',
#  'Dalry Road Co-op',
#  'Dalry Road Lidl',
#  'Dean Street',
#  'Depot',
#  'Depot Virtual',
#  'Drummond Street',
#  'Dudley Gardens',
#  'Duke Street',
#  'Dundas Street',
#  'Dynamic Earth',
#  'Edinburgh Park Central',
#  'Edinburgh Park Station',
#  'Edinburgh Royal Infirmary',
#  'Fort Kinnaird',
#  "Gamekeeper's Road",
#  'George Square',
#  'Gorgie Road',
#  'Hawes Pier',
#  'Henderson Row',
#  'Heriot Watt - Edinburgh Business School',
#  'Hillside Crescent',
#  'Hillside Crescent 1',
#  'Hillside Crescent 2',
#  'Holyrood Road',
#  'Hopetoun Road',
#  'IGMM',
#  'IGMM - Western General',
# ...

# %%
# stanice, kde kola chybi
chybi
# Out:
# ['Belford Road',
#  'Borrowman Square',
#  'Bristo Square',
#  'Bruntsfield',
#  'Bruntsfield Links',
#  'Bruntsfield links',
#  'Castle Street',
#  'Castle Terrace',
#  'Causewayside',
#  'Chambers Street',
#  'Charlotte Square',
#  'City Chambers',
#  'Colinton Road',
#  'Crichton Street',
#  'Dalmeny Station',
#  'Drumsheugh Place',
#  'Dunbar’s Close Garden',
#  'Dundee Terrace',
#  'EICC',
#  'East London Street',
#  'Eden Locke - Aparthotel (RESIDENTS ONLY)',
#  'Edinburgh Zoo',
#  'Ellersly Road',
#  'Forth Bridge Visitors Centre',
#  'Fountain Court  - Apartments (RESIDENTS ONLY)',
#  'Fountainbridge',
#  'Gibson Terrace',
#  'Gladstone Terrace',
#  'Grassmarket',
#  'HSBC UK Lets Ride - Meadows Event',
#  'Haymarket - Murrayfield Rugby Event',
#  'Haymarket Station',
#  'Haymarket Terrace',
#  'Heriot Watt - Student Accommodation',
#  'Heriot Watt - Student Accomodation (Anna MacLeod Halls)',
#  "Holyrood Park - Woman's Tour Of Scotland (Event 11/08/19)",
# ...

# %%
# stanice beze zmeny
stejne_zacatek_konec
# Out:
# ['Crescent House', 'Picady Place']

# %%
# vzdalenost mezi stanicemi
# nejprve si vytvorim sloupec date (budu ho potrebovat na spojeni tabulek k vypoctu vzdalenosti a na spojeni tabulek o pocasi a o kolech)
# pak si vytvorim tabulku zacatek vypujcky a souradnice 
# pak si vytvorim tabulku konecvypujcky a souradnice 
# tvorba indexu pro join, pak spojim a vypoctu vzdalenosti
# pak odstranim index a prevedu na list

# %%
# tvorba sloupce date - tabulka zacatek vypujcky
eb_df_date=eb_df
eb_df_date['date']=pd.to_datetime(eb_df['started_at']).dt.date

eb_df_start=eb_df_date[["date","start_station_name","start_station_latitude","start_station_longitude"]]
eb_df_start=eb_df_start.drop_duplicates("start_station_name")
eb_df_start.head()
# Out:
#          date  ... start_station_longitude
# 0  2018-09-15  ...               -3.207101
# 1  2018-09-15  ...               -3.192774
# 2  2018-09-15  ...               -3.196284
# 3  2018-09-16  ...               -3.176902
# 5  2018-09-16  ...               -3.171646
#
# [5 rows x 4 columns]

# %%
# tvorba sloupce date - tabulka konec vypujcky
eb_df_konec=eb_df_date[["date","end_station_name","end_station_latitude","end_station_longitude"]]
eb_df_konec=eb_df_konec.drop_duplicates("end_station_name")
eb_df_konec.head()
# Out:
#          date  end_station_name  end_station_latitude  end_station_longitude
# 0  2018-09-15  St Andrew Square             55.954728              -3.192653
# 1  2018-09-15        Canonmills             55.962804              -3.196284
# 2  2018-09-15     Victoria Quay             55.977638              -3.174116
# 3  2018-09-16  Kings Building 3             55.923479              -3.175385
# 4  2018-09-16  Kings Building 2             55.923202              -3.171646

# %%
# index na date - tabulka zacatek vypujcky
eb_df_start_index=eb_df_start.set_index('date') 
cols=["start_station_name","start_station_latitude","start_station_longitude"]
eb_df_start_index=eb_df_start_index[cols]
eb_df_start_index.head()
# Out:
#            start_station_name  start_station_latitude  start_station_longitude
# date
# 2018-09-15   Charlotte Square               55.952335                -3.207101
# 2018-09-15   St Andrew Square               55.954749                -3.192774
# 2018-09-15         Canonmills               55.962804                -3.196284
# 2018-09-16  Kings Buildings 4               55.922001                -3.176902
# 2018-09-16   Kings Building 2               55.923202                -3.171646

# %%
# index na date - tabulka konec vypujcky
eb_df_konec_index=eb_df_konec.set_index('date') 
cols=["end_station_name","end_station_latitude","end_station_longitude"]
eb_df_konec_index=eb_df_konec_index[cols]
eb_df_konec_index.head()
# Out:
#             end_station_name  end_station_latitude  end_station_longitude
# date
# 2018-09-15  St Andrew Square             55.954728              -3.192653
# 2018-09-15        Canonmills             55.962804              -3.196284
# 2018-09-15     Victoria Quay             55.977638              -3.174116
# 2018-09-16  Kings Building 3             55.923479              -3.175385
# 2018-09-16  Kings Building 2             55.923202              -3.171646

# %%
# spojeni tabulek pro vypocet vzdalenosti
spoj_pro_vypocet=eb_df_start_index.join(eb_df_konec_index).dropna()
spoj_pro_vypocet.head()
# Out:
#            start_station_name  ...  end_station_longitude
# date                           ...
# 2018-09-15   Charlotte Square  ...              -3.192653
# 2018-09-15   Charlotte Square  ...              -3.196284
# 2018-09-15   Charlotte Square  ...              -3.174116
# 2018-09-15   St Andrew Square  ...              -3.192653
# 2018-09-15   St Andrew Square  ...              -3.196284
#
# [5 rows x 6 columns]

# %%
# vzdalenost mezi stanicemi
from geopy.distance import geodesic
from itertools import combinations
@np.vectorize
def vzdalenost(lat1, lon1, lat2, lon2):
    rs = geodesic( (lat1, lon1), (lat2, lon2) ).kilometers
    return rs


dv = vzdalenost(spoj_pro_vypocet['start_station_latitude'].to_numpy(), spoj_pro_vypocet['start_station_longitude'].to_numpy(),
                  spoj_pro_vypocet['end_station_latitude'].to_numpy(), spoj_pro_vypocet['end_station_longitude'].to_numpy(), )

spoj_pro_vypocet["vzdalenost_v_km"] = dv.round(2)
spoj_pro_vypocet=spoj_pro_vypocet[["start_station_name","end_station_name","vzdalenost_v_km"]]
spoj_pro_vypocet.round(2).head()
# Out:
#            start_station_name  end_station_name  vzdalenost_v_km
# date
# 2018-09-15   Charlotte Square  St Andrew Square             0.94
# 2018-09-15   Charlotte Square        Canonmills             1.35
# 2018-09-15   Charlotte Square     Victoria Quay             3.49
# 2018-09-15   St Andrew Square  St Andrew Square             0.01
# 2018-09-15   St Andrew Square        Canonmills             0.92

# %%
# odstraneni indexu, aby mohla prevest na list
spoj_pro_vypocet_prehled=spoj_pro_vypocet.reset_index()
spoj_pro_vypocet_prehled.head()
# Out:
#          date start_station_name  end_station_name  vzdalenost_v_km
# 0  2018-09-15   Charlotte Square  St Andrew Square             0.94
# 1  2018-09-15   Charlotte Square        Canonmills             1.35
# 2  2018-09-15   Charlotte Square     Victoria Quay             3.49
# 3  2018-09-15   St Andrew Square  St Andrew Square             0.01
# 4  2018-09-15   St Andrew Square        Canonmills             0.92

# %%
# prevod do listu
prehled_vzdalenosti=[]
dspvp=spoj_pro_vypocet_prehled.shape
for i in range(dspvp[0]):
  prehled_vzdalenosti.append((str(spoj_pro_vypocet_prehled["start_station_name"].loc[i])+" a "+str(spoj_pro_vypocet_prehled["end_station_name"].loc[i])+" je "+str(spoj_pro_vypocet_prehled["vzdalenost_v_km"].loc[i])+" km"))
prehled_vzdalenosti
# Out:
# ['Charlotte Square a St Andrew Square je 0.94 km',
#  'Charlotte Square a Canonmills je 1.35 km',
#  'Charlotte Square a Victoria Quay je 3.49 km',
#  'St Andrew Square a St Andrew Square je 0.01 km',
#  'St Andrew Square a Canonmills je 0.92 km',
#  'St Andrew Square a Victoria Quay je 2.8 km',
#  'Canonmills a St Andrew Square je 0.93 km',
#  'Canonmills a Canonmills je 0.0 km',
#  'Canonmills a Victoria Quay je 2.15 km',
#  'Kings Buildings 4 a Kings Building 3 je 0.19 km',
#  'Kings Buildings 4 a Kings Building 2 je 0.35 km',
#  'Kings Buildings 4 a Kings Buildings 1 je 0.31 km',
#  'Kings Buildings 4 a Pollock Halls je 2.03 km',
#  'Kings Buildings 4 a Royal Commonwealth Pool je 1.9 km',
#  'Kings Buildings 4 a Meadows East je 2.02 km',
#  'Kings Buildings 4 a Bristo Square je 2.77 km',
#  'Kings Building 2 a Kings Building 3 je 0.24 km',
#  'Kings Building 2 a Kings Building 2 je 0.0 km',
#  'Kings Building 2 a Kings Buildings 1 je 0.18 km',
# ...

# %%
# histogram s delkou vypujcky

histogram=eb_df
np.log(histogram['duration']).hist(edgecolor='k',figsize=(10,8),bins=30);

# %%
# delka vypujcky - nejkratsi / nejdelsi
delka_vypujcky = eb_df['duration']
delka_vypujcky.sort_values()
# Out:
# 394691         61
# 11354          61
# 400319         61
# 290303         61
# 217194         61
#            ...
# 14913      688832
# 161588     701168
# 13026     1000750
# 141002    1032838
# 12423     2363348
# Name: duration, Length: 438259, dtype: int64

# %%
# prepocet nejdelsi vypujcky na dny
nejdelsi=2363348/60/60/24
nejdelsi
# Out:
# 27.353564814814813

# %%
# prumerna delka vypujcky - prepocet na minuty
prumer_vypujcky=delka_vypujcky.mean()/60
prumer_vypujcky
# Out:
# 32.48063397823357

# %%
# zjisteni odlehle hodnoty - dala jsem limit mezi nadchazejici a predeslou hodnotou 500 000 vterin
odlehla=eb_df[["index","duration"]]
odlehla.sort_values("duration")
rozdil=[]
for i in range(len(odlehla)-1):
  roz=(odlehla["duration"].loc[i+1])-(odlehla["duration"].loc[i])
  if roz>=500000:
    rozdil.append(("index = "+str(odlehla["index"].loc[i+1]),"odlehla hodnota = "+str(odlehla["duration"].loc[i+1])))
rozdil
# Out:
# [('index = 1322', 'odlehla hodnota = 500807'),
#  ('index = 2130', 'odlehla hodnota = 2363348'),
#  ('index = 2733', 'odlehla hodnota = 1000750'),
#  ('index = 766', 'odlehla hodnota = 688832'),
#  ('index = 3151', 'odlehla hodnota = 631452'),
#  ('index = 2206', 'odlehla hodnota = 1032838'),
#  ('index = 3445', 'odlehla hodnota = 701168')]

# %%
#pretypovani sloupce started_at a endet_at ze str na datetime
eb_df['started_at'] = pd.to_datetime(eb_df['started_at'])
eb_df['ended_at'] = pd.to_datetime(eb_df['ended_at'])

# %%
#vyvoj pujcovani kol v case - datum a 
za_rok = {}
for i in eb_df["started_at"]:
    key = i.year
    if not key in za_rok:
        za_rok[key] = 0
    za_rok[key] += 1


prevod_roky=list(za_rok.keys())
prevod_roky_hodnoty=list(za_rok.values())
prevod_roky_hodnoty

#graf dle let
x = np.arange(len(prevod_roky))
width = 0.5

fig, ax = plt.subplots(figsize=(10,4))
rects1 = ax.bar(x - width/2, prevod_roky_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle roku')
ax.set_title('Prehled vypujcek kol dle jednotlivych roku')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(prevod_roky)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_roku.png")
# Out:
# No handles with labels found to put in legend.

# %%
# grafy dle mesicu
za_mesic = {}
for i in eb_df["started_at"]:
    key = (i.year, i.month)
    if not key in za_mesic:
        za_mesic[key] = 0
    za_mesic[key] += 1
prevod_mesice=list(za_mesic.keys()) # prevod klice dict na list kvuli grafu

#vyber dle mesicu hodnota
mesice=[]
for i in range(len(prevod_mesice)):
     mesice.append(prevod_mesice[i][1])

# grafy dny
za_den = {}
for i in eb_df["started_at"]:
    key = (i.year, i.month,i.day)
    if not key in za_den:
        za_den[key] = 0
    za_den[key] += 1


prehled_dle_dnu=list(za_den.keys()) # prevod klice dict na list kvuli grafu
dny=[] 
for i in range(len(prehled_dle_dnu)):
  dny.append(prehled_dle_dnu[i][2])
prehled_dle_dnu[0][0]

mesice_ke_dnum=[] 
for i in range(len(prehled_dle_dnu)):
  mesice_ke_dnum.append(prehled_dle_dnu[i][1])

# %%
# tvorba listu pro grafy
delka=eb_df.shape
roky=[2018,2019,2020,2021]
rok_2018_mesic=[]
rok_2019_mesic=[]
rok_2020_mesic=[]
rok_2021_mesic=[]

rok_2018_dny=[]
rok_2019_dny=[]
rok_2020_dny=[]
rok_2021_dny=[]



rok_2018_mesice_hodnoty=[]
rok_2018_dny_hodnoty=[]
napln_mesic=[rok_2018_mesic,rok_2019_mesic,rok_2020_mesic,rok_2021_mesic]
for i in range(len(roky)): 
  for j in range(len(prevod_mesice)):
    if prevod_mesice[j][0]==roky[i]:
      napln_mesic[i].append((str(prevod_mesice[j][1])+'/'+str(roky[i])))

napln_dny=[rok_2018_dny,rok_2019_dny,rok_2020_dny,rok_2021_dny]
for i in range(len(napln_dny)):
  for j in range(len(prehled_dle_dnu)):
    if prehled_dle_dnu[j][0]==roky[i]:
      napln_dny[i].append((str(prehled_dle_dnu[j][2])+'/'+str(prehled_dle_dnu[j][0])))



rok_2021_mesice_hodnoty=[]
rok_2019_mesice_hodnoty=[]
rok_2020_mesice_hodnoty=[]
rok_2021_mesice_hodnoty=[]
hodnota_mesice=[rok_2018_mesice_hodnoty,rok_2019_mesice_hodnoty,rok_2020_mesice_hodnoty,rok_2021_mesice_hodnoty]
prevod_mesice_hodnota=list(za_mesic.values())
for i in range(len(hodnota_mesice)):#4 
  for j in range(len(prevod_mesice_hodnota)):#34
    if prevod_mesice[j][0]==roky[i]:
      hodnota_mesice[i].append(prevod_mesice_hodnota[j])


rok_2018_dny_hodnoty=[]
rok_2019_dny_hodnoty=[]
rok_2020_dny_hodnoty=[]
rok_2021_dny_hodnoty=[]
hodnota_roky_dny=[rok_2018_dny_hodnoty,rok_2019_dny_hodnoty,rok_2020_dny_hodnoty,rok_2021_dny_hodnoty]
prehled_dle_dnu=list(za_den.keys())
prevod_dle_dnu_hodnota=list(za_den.values())
for i in range(len(hodnota_roky_dny)):#4 
  for j in range(len(prevod_dle_dnu_hodnota)): #1020
    if prehled_dle_dnu[j][0]==roky[i]:
      hodnota_roky_dny[i].append(prevod_dle_dnu_hodnota[j])

cele_obdobi_dny=prehled_dle_dnu
cele_obdobi_hodnoty=prevod_dle_dnu_hodnota

# %%
#graf vse dle dni
x = np.arange(len(cele_obdobi_dny))  
width = 0.5  

fig, ax = plt.subplots(figsize=(30,4))
rects1 = ax.bar(x - width/2, cele_obdobi_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle dnu')
ax.set_title('Prehled vypujcek kol dle jednotlivych dnu - rok 2018 - 2021')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(cele_obdobi_dny)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_dnu_2018_2021.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2018
x = np.arange(len(rok_2018_mesic))  
width = 0.5  

fig, ax = plt.subplots(figsize=(20,4))
rects1 = ax.bar(x - width/2, rok_2018_mesice_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle mesicu')
ax.set_title('Prehled vypujcek kol dle jednotlivych mesicu - rok 2018')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2018_mesic)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_mesicu_2018.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2019
x = np.arange(len(rok_2019_mesic))  
width = 0.5  

fig, ax = plt.subplots(figsize=(20,4))
rects1 = ax.bar(x - width/2, rok_2019_mesice_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle mesicu')
ax.set_title('Prehled vypujcek kol dle jednotlivych mesicu - rok 2019')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2019_mesic)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_mesicu_2019.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2020
x = np.arange(len(rok_2020_mesic))  
width = 0.5  

fig, ax = plt.subplots(figsize=(20,4))
rects1 = ax.bar(x - width/2, rok_2020_mesice_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle mesicu')
ax.set_title('Prehled vypujcek kol dle jednotlivych mesicu - rok 2020')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2020_mesic)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_mesicu_2020.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2021
x = np.arange(len(rok_2021_mesic))  
width = 0.5  

fig, ax = plt.subplots(figsize=(20,4))
rects1 = ax.bar(x - width/2, rok_2021_mesice_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle mesicu')
ax.set_title('Prehled vypujcek kol dle jednotlivych mesicu - rok 2021')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2021_mesic)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_mesicu_2021.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2018 dle dni
x = np.arange(len(rok_2018_dny))  
width = 0.5  

fig, ax = plt.subplots(figsize=(30,4))
rects1 = ax.bar(x - width/2, rok_2018_dny_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle dnu')
ax.set_title('Prehled vypujcek kol dle jednotlivych dnu - rok 2018')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2018_dny)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_dnu_2018.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2019 dle dni
x = np.arange(len(rok_2019_dny))  
width = 0.5  

fig, ax = plt.subplots(figsize=(30,4))
rects1 = ax.bar(x - width/2, rok_2019_dny_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle dnu')
ax.set_title('Prehled vypujcek kol dle jednotlivych dnu - rok 2019')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2019_dny)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_dnu_2019.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf graf 2020 dle dni
x = np.arange(len(rok_2020_dny))  
width = 0.5  

fig, ax = plt.subplots(figsize=(30,4))
rects1 = ax.bar(x - width/2, rok_2020_dny_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle mesicu')
ax.set_title('Prehled vypujcek kol dle jednotlivych dnu - rok 2020')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2020_dny)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_dnu_2020.png")
# Out:
# No handles with labels found to put in legend.

# %%
#graf rok 2021 dle dni
x = np.arange(len(rok_2021_dny))  
width = 0.5  

fig, ax = plt.subplots(figsize=(30,4))
rects1 = ax.bar(x - width/2, rok_2021_dny_hodnoty, width)

ax.set_ylabel('Pocet vypujcek dle dnu')
ax.set_title('Prehled vypujcek kol dle jednotlivych dnu - rok 2021')
ax.set_xticks(x)
ax.grid()
ax.set_xticklabels(rok_2021_dny)
ax.legend()



fig.tight_layout()
plt.show()
plt.savefig("plot_dle_dnu_2021.png")
# Out:
# No handles with labels found to put in legend.

# %%
#vliv pocasi na poptavku
#pridani sloupce date do tabulky o kolech kvuli joinu
eb_df_date=eb_df
eb_df_date['date']=pd.to_datetime(eb_df['started_at']).dt.date

#prevod sloupce date z object na datetime - tabulka o kolech
eb_df_date_datetime=pd.to_datetime(eb_df_date["date"])
eb_df_date_datetime=pd.DataFrame(eb_df_date_datetime)
eb_df_date_datetime.head()
eb_df_date_datetime["duration"]=eb_df["duration"]

#grup dle data - tabulka o kolech
grup_kola=eb_df_date_datetime.groupby('date')[['duration']].mean().round()

eb_df_date_datetime
# Out:
#              date  duration
# 0      2018-09-15      1182
# 1      2018-09-15       995
# 2      2018-09-15      3466
# 3      2018-09-16      1430
# 4      2018-09-16       452
# ...           ...       ...
# 438254 2021-06-30      2139
# 438255 2021-06-30      1763
# 438256 2021-06-30      1342
# 438257 2021-06-30      1369
# 438258 2021-06-30       522
#
# [438259 rows x 2 columns]

# %%
#prevod sloupce date z object na datetime - tabulka o pocasi
ew_df_date_datetime=pd.to_datetime(ew_df["date"])
ew_df_date_datetime=pd.DataFrame(ew_df_date_datetime)
ew_df_date_datetime
# Out:
#            date
# 0    2018-09-01
# 1    2018-09-01
# 2    2018-09-01
# 3    2018-09-01
# 4    2018-09-01
# ...         ...
# 8267 2021-06-30
# 8268 2021-06-30
# 8269 2021-06-30
# 8270 2021-06-30
# 8271 2021-06-30
#
# [8272 rows x 1 columns]

# %%
# delka tabulky o pocasi
dew=ew_df_date_datetime.shape

# %%
# pretypovani vybranych sloupcu tabulky o pocasi na int, abych mohla zprumerovat a grupovat dle dnu 
sloupec_temp=[]
sloupec_feels=[]
sloupec_wind=[]
sloupec_gust=[]
sloupec_rain=[]
for i in range(dew[0]):
  sloupec_temp.append(int((ew_df[['temp']].loc[i][0])[:2]))
  sloupec_feels.append(int((ew_df[['feels']].loc[i][0])[:2]))
  sloupec_wind.append(int((ew_df[['wind']].loc[i][0])[:2]))
  sloupec_gust.append(int((ew_df[['gust']].loc[i][0])[:2]))
  sloupec_rain.append(float((ew_df[['rain']].loc[i][0])[:3]))
ew_df_date_datetime['pretyp_temp']=sloupec_temp
ew_df_date_datetime['pretyp_feels']=sloupec_feels
ew_df_date_datetime['pretyp_wind']=sloupec_wind
ew_df_date_datetime['pretyp_gust']=sloupec_gust
ew_df_date_datetime['pretyp_rain']=sloupec_rain
ew_df_date_datetime
# Out:
#            date  pretyp_temp  ...  pretyp_gust  pretyp_rain
# 0    2018-09-01           11  ...           19          0.0
# 1    2018-09-01           13  ...           19          0.0
# 2    2018-09-01           14  ...           19          0.0
# 3    2018-09-01           14  ...           23          0.1
# 4    2018-09-01           16  ...           22          0.0
# ...         ...          ...  ...          ...          ...
# 8267 2021-06-30           14  ...           14          0.0
# 8268 2021-06-30           16  ...           14          0.0
# 8269 2021-06-30           17  ...           12          0.0
# 8270 2021-06-30           16  ...           15          0.0
# 8271 2021-06-30           13  ...           12          0.0
#
# [8272 rows x 6 columns]

# %%
# zjisteni prumeru na den
prumer_ew=ew_df_date_datetime.groupby('date').mean().round(2)
prumer_ew
# Out:
#             pretyp_temp  pretyp_feels  pretyp_wind  pretyp_gust  pretyp_rain
# date
# 2018-09-01        14.38         14.00        12.12        20.12         0.01
# 2018-09-02        16.50         16.62        12.88        21.00         0.05
# 2018-09-03        11.88         11.50         8.62        13.12         0.04
# 2018-09-04        11.25         13.38         5.00         6.75         0.00
# 2018-09-05        12.50         12.62         9.38        14.12         0.05
# ...                 ...           ...          ...          ...          ...
# 2021-06-26        11.25         10.75         6.12         8.25         0.19
# 2021-06-27        14.25         14.25         2.88         4.88         0.01
# 2021-06-28        17.75         18.25         4.38         6.50         0.01
# 2021-06-29        16.50         16.50         7.88        10.75         0.00
# 2021-06-30        14.12         13.62         9.88        12.75         0.00
#
# [1034 rows x 5 columns]

# %%
#index na date - tabulka o pocasi
eb_df_date_index=eb_df_date_datetime.set_index('date') 
cols=['duration']
eb_df_date_index=eb_df_date_index[cols]
eb_df_date_index.head()
# Out:
#             duration
# date
# 2018-09-15      1182
# 2018-09-15       995
# 2018-09-15      3466
# 2018-09-16      1430
# 2018-09-16       452

# %%
#index na date - tabulka o kolech
ew_df_date_index=ew_df_date_datetime.set_index('date') 
cols=['pretyp_temp','pretyp_feels','pretyp_wind','pretyp_gust','pretyp_rain']
ew_df_date_index=ew_df_date_index[cols]
ew_df_date_index.head()
# Out:
#             pretyp_temp  pretyp_feels  pretyp_wind  pretyp_gust  pretyp_rain
# date
# 2018-09-01           11            11            9           19          0.0
# 2018-09-01           13            12           11           19          0.0
# 2018-09-01           14            13           11           19          0.0
# 2018-09-01           14            13           14           23          0.1
# 2018-09-01           16            16           15           22          0.0

# %%
# prumer vzdalenosti na den
prumer_eb=eb_df_date_index.groupby("date").mean().round()
prumer_eb.head()
# Out:
#             duration
# date
# 2018-09-15    1881.0
# 2018-09-16     646.0
# 2018-09-17    1564.0
# 2018-09-18    1780.0
# 2018-09-19    2252.0

# %%
# spojeni zprumerovane a zgrupovane tabulky o kolech a o pocasi - budu z ni tvorit graf "vliv pocasi na poptavku"
spojeni=prumer_eb.join(prumer_ew)
spojeni.sort_values(["duration","pretyp_gust","pretyp_wind","pretyp_rain","pretyp_feels","pretyp_rain"]).round(2).head(50)

spojeni.sort_values((["duration","pretyp_gust"]),ascending=False).round(2).head()
# Out:
#             duration  pretyp_temp  ...  pretyp_gust  pretyp_rain
# date                               ...
# 2018-12-18   22259.0         8.62  ...        38.62         0.35
# 2018-12-22    9541.0         5.88  ...        31.50         0.00
# 2019-02-23    7434.0         9.88  ...        33.88         0.00
# 2019-01-05    6575.0         3.12  ...        25.75         0.00
# 2018-10-14    5752.0         8.88  ...        17.88         0.00
#
# [5 rows x 6 columns]

# %%
# pridala jsem do spojene tabulky sloupec podil_duration (podil 100 sloupce duration) - aby byly hodnoty blizsi ostatnim hodnotam a lepe se orientovalo v grafu
podil_duration=[]
spojeni_podil=spojeni.reset_index()

for i in range(len(spojeni_podil)):
  podil_duration.append((spojeni_podil["duration"][i]/100))
podil_duration

spojeni_podil["podil_duration"]=podil_duration
spojeni_podil.head()
# Out:
#         date  duration  pretyp_temp  ...  pretyp_gust  pretyp_rain  podil_duration
# 0 2018-09-15    1881.0        10.50  ...        23.50         0.12           18.81
# 1 2018-09-16     646.0        12.88  ...        43.12         0.12            6.46
# 2 2018-09-17    1564.0        13.88  ...        29.88         0.02           15.64
# 3 2018-09-18    1780.0        14.12  ...        28.50         0.24           17.80
# 4 2018-09-19    2252.0        11.75  ...        55.62         0.36           22.52
#
# [5 rows x 8 columns]

# %%
# graf vliv pocasi na poptavku za cele obdobi
fig = plt.figure(figsize=(30, 20))
pocasi = plt.subplot2grid((2,2), (1,0), colspan=2, fig=fig)

colors = {"podil_duration": "black",'pretyp_temp': 'orange', "pretyp_feels": "pink",'pretyp_wind': "green",'pretyp_gust': "yellow", 'pretyp_rain': "red"}
spojeni_podil[colors.keys()].plot(ax=pocasi, linewidth=4, color=colors.values()) #color.keys vyberu sloupce ve stejnem poradi
pocasi.grid(alpha=0.4)
pocasi.legend(fontsize=80,loc=1, ncol=6)

pocasi.set_ylabel('Prehled vypujcek dle pocasi - hodnoty')
pocasi.set_title('Prehled vypujcek dle pocasi - 2018 - 2021')
pocasi.set_xticks(x)
pocasi.grid()
pocasi.set_xticklabels("datum")
pocasi.legend()
plt.tight_layout()
plt.savefig("vliv pocasi na poptavku.png")

# %%
#identifikace priciny vykyvu poptavky - zvysena nad 1500
vykyvy_nahoru_1500=[]
for i in range(len(cele_obdobi_hodnoty)):
  if cele_obdobi_hodnoty[i]>1500:
    vykyvy_nahoru_1500.append((cele_obdobi_dny[i],cele_obdobi_hodnoty[i]))
vykyvy_nahoru_1500
# Out:
# [((2020, 5, 20), 1589),
#  ((2020, 5, 25), 1721),
#  ((2020, 5, 28), 1522),
#  ((2020, 5, 29), 1832),
#  ((2020, 5, 30), 2065),
#  ((2020, 5, 31), 2036),
#  ((2020, 6, 1), 1578),
#  ((2020, 6, 6), 1539),
#  ((2020, 6, 20), 2428),
#  ((2020, 6, 24), 1646),
#  ((2020, 6, 25), 1644),
#  ((2020, 7, 11), 1573),
#  ((2020, 7, 31), 1591),
#  ((2020, 8, 8), 1700)]

# %%
#identifikace priciny vykyvu poptavky - snizena pod 100
vykyvy_dolu_100=[]
for i in range(len(cele_obdobi_hodnoty)):
  if cele_obdobi_hodnoty[i]<100:
    vykyvy_dolu_100.append((cele_obdobi_dny[i],cele_obdobi_hodnoty[i]))
vykyvy_dolu_100
# Out:
# [((2018, 9, 15), 3),
#  ((2018, 9, 16), 10),
#  ((2018, 9, 19), 77),
#  ((2018, 9, 21), 94),
#  ((2018, 10, 1), 84),
#  ((2018, 10, 7), 81),
#  ((2018, 10, 8), 82),
#  ((2018, 10, 9), 90),
#  ((2018, 10, 12), 80),
#  ((2018, 10, 13), 49),
#  ((2018, 10, 24), 99),
#  ((2018, 11, 20), 81),
#  ((2018, 11, 22), 92),
#  ((2018, 11, 24), 94),
#  ((2018, 12, 4), 99),
#  ((2018, 12, 7), 89),
#  ((2018, 12, 23), 98),
#  ((2018, 12, 24), 61),
#  ((2018, 12, 26), 95),
#  ((2019, 2, 2), 80),
#  ((2019, 2, 3), 91),
#  ((2019, 2, 9), 95),
#  ((2019, 3, 10), 65),
#  ((2019, 3, 16), 59),
#  ((2019, 4, 6), 89),
#  ((2019, 4, 7), 79),
#  ((2020, 12, 26), 64),
#  ((2020, 12, 29), 75),
#  ((2020, 12, 31), 84),
#  ((2021, 1, 2), 82),
#  ((2021, 1, 3), 53),
#  ((2021, 1, 4), 72),
#  ((2021, 1, 7), 97),
#  ((2021, 1, 20), 90),
#  ((2021, 1, 21), 71),
#  ((2021, 2, 3), 95),
#  ((2021, 2, 9), 50),
#  ((2021, 2, 10), 60),
#  ((2021, 2, 11), 63),
#  ((2021, 2, 12), 99),
#  ((2021, 2, 13), 91),
# ...

# %%
# vykyvy poptavky nad 150 - filtrace teploty, vetru a narazoveho vetru
dv_1500=len(vykyvy_nahoru_1500)
vykyvy_1500=[]
for i in range(dv_1500):
  if vykyvy_nahoru_1500[i][1]>1500:
    vykyvy_1500.append(("datum "+str(vykyvy_nahoru_1500[i][0][2])+"/"+str(vykyvy_nahoru_1500[i][0][1])+"/"+str(vykyvy_nahoru_1500[i][0][0]),"teplota "+str(spojeni_podil["pretyp_temp"].loc[i]),"vitr "+str(spojeni_podil["pretyp_wind"].loc[i]),"narazovy vitr "+str(spojeni_podil["pretyp_gust"].loc[i])))
vykyvy_1500
# Out:
# [('datum 20/5/2020', 'teplota 10.5', 'vitr 14.88', 'narazovy vitr 23.5'),
#  ('datum 25/5/2020', 'teplota 12.88', 'vitr 26.5', 'narazovy vitr 43.12'),
#  ('datum 28/5/2020', 'teplota 13.88', 'vitr 18.0', 'narazovy vitr 29.88'),
#  ('datum 29/5/2020', 'teplota 14.12', 'vitr 16.88', 'narazovy vitr 28.5'),
#  ('datum 30/5/2020', 'teplota 11.75', 'vitr 34.75', 'narazovy vitr 55.62'),
#  ('datum 31/5/2020', 'teplota 10.12', 'vitr 21.5', 'narazovy vitr 31.88'),
#  ('datum 1/6/2020', 'teplota 8.88', 'vitr 21.88', 'narazovy vitr 33.75'),
#  ('datum 6/6/2020', 'teplota 8.88', 'vitr 21.0', 'narazovy vitr 33.0'),
#  ('datum 20/6/2020', 'teplota 7.5', 'vitr 12.25', 'narazovy vitr 19.75'),
#  ('datum 24/6/2020', 'teplota 8.62', 'vitr 16.75', 'narazovy vitr 27.0'),
#  ('datum 25/6/2020', 'teplota 10.5', 'vitr 26.38', 'narazovy vitr 40.5'),
#  ('datum 11/7/2020', 'teplota 15.38', 'vitr 32.38', 'narazovy vitr 51.5'),
#  ('datum 31/7/2020', 'teplota 12.5', 'vitr 24.12', 'narazovy vitr 38.88'),
# ...

# %%
# vykyvy poptavky pod 100 - filtrace teploty, vetru a narazoveho vetru
dv_100=len(vykyvy_dolu_100)
vykyvy_100=[]
for i in range(dv_100):
  if vykyvy_dolu_100[i][1]<100:
    vykyvy_100.append(("datum "+str(vykyvy_dolu_100[i][0][2])+"/"+str(vykyvy_dolu_100[i][0][1])+"/"+str(vykyvy_dolu_100[i][0][0]),"teplota "+str(spojeni_podil["pretyp_temp"].loc[i]),"vitr "+str(spojeni_podil["pretyp_wind"].loc[i]),"narazovy vitr "+str(spojeni_podil["pretyp_gust"].loc[i])))
vykyvy_100
# Out:
# [('datum 15/9/2018', 'teplota 10.5', 'vitr 14.88', 'narazovy vitr 23.5'),
#  ('datum 16/9/2018', 'teplota 12.88', 'vitr 26.5', 'narazovy vitr 43.12'),
#  ('datum 19/9/2018', 'teplota 13.88', 'vitr 18.0', 'narazovy vitr 29.88'),
#  ('datum 21/9/2018', 'teplota 14.12', 'vitr 16.88', 'narazovy vitr 28.5'),
#  ('datum 1/10/2018', 'teplota 11.75', 'vitr 34.75', 'narazovy vitr 55.62'),
#  ('datum 7/10/2018', 'teplota 10.12', 'vitr 21.5', 'narazovy vitr 31.88'),
#  ('datum 8/10/2018', 'teplota 8.88', 'vitr 21.88', 'narazovy vitr 33.75'),
#  ('datum 9/10/2018', 'teplota 8.88', 'vitr 21.0', 'narazovy vitr 33.0'),
#  ('datum 12/10/2018', 'teplota 7.5', 'vitr 12.25', 'narazovy vitr 19.75'),
#  ('datum 13/10/2018', 'teplota 8.62', 'vitr 16.75', 'narazovy vitr 27.0'),
#  ('datum 24/10/2018', 'teplota 10.5', 'vitr 26.38', 'narazovy vitr 40.5'),
#  ('datum 20/11/2018', 'teplota 15.38', 'vitr 32.38', 'narazovy vitr 51.5'),
# ...

# %%
#zjisteni, kolikrat se pujcilo kolo o vikendu - zacatek vypujcky
tyden=eb_df['weekday'] = eb_df['started_at'].dt.weekday
mesic=eb_df['month'] = eb_df['started_at'].dt.month
vse=eb_df[['started_at', 'weekday', 'month']]


vikend_z=[]
vsedni_den_z=[]
for i in tyden:
  if i==5 or i==6:
    vikend_z.append(1)
  else:
    vsedni_den_z.append(1)
len(vikend_z)
# Out:
# 137895

# %%
#zjisteni, kolikrat se pujcilo kolo o vikendu - konec vypujcky
tyden_konec=eb_df['ended_at'].dt.weekday
mesic_konec=eb_df['ended_at'].dt.month
vse_konec=eb_df[['started_at', 'weekday', 'month']]

vikend_k=[]
vsedni_den_k=[]
for i in tyden_konec:
  if i==5 or i==6:
    vikend_k.append(1)
  else:
    vsedni_den_k.append(1)
len(vikend_k)
# Out:
# 138034

# %%
#zjisteni, kolikrat se pujcilo kolo ve vsedni den - zacatek vypujcky
len(vsedni_den_z)
# Out:
# 300364

# %%
#zjisteni, kolikrat se pujcilo kolo ve vsedni den - konec vypujcky
len(vsedni_den_k)
# Out:
# 300225
